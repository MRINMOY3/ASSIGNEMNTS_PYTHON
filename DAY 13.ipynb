# %% [markdown]
# # Python Tasks – Day13
#
#
#
# # Write a Python Code to count the Number of Each Vowel in a given string
#
# # Write a Python Code to count number of words, characters and number of spaces in a given string
#
# # Write a Python Program to remove punctuation from a given string (using loop)
#
# # Write a Python Program to take a mxn matrix input from user and stored in nested list
#
# # Write a Python Program to add, multiply and transpose two matrices given by user

# %%
a=input("Enter a Sentence / String ")
arr=[]
cnt=0
individual=[]
# print(dir(str))
# print(len(a))
i=0
cnt=[0,0,0,0,0]
vowel=['a','e','i','o','u']
for i in range(len(a)):
   print(a[i],end=" ")
   if(a[i] == 'a' or a[i]=="A"):
      cnt[0]+=1
   elif(a[i] == 'e' or a[i]=="E"):
      cnt[1]+=1
   elif(a[i] == 'i' or a[i]=="I"):
      cnt[2]+=1
   elif(a[i] == 'o' or a[i]=="O"):
      cnt[3]+=1
   elif(a[i] == 'u' or a[i]=="U"):
      cnt[4]+=1
      

for i in range(5):
   print(f"The number of occurances of {vowel[i]} = {cnt[i]} ")
   

   





# b=a.strip().split()
# print(b)
# arr=b

# for i in range(len(arr)):
#     individual.append(arr[i].strip())
#     print(arr[i])

# print(individual,end=" ")
# for i in range(len(arr)):
#  print(individual[i].strip().strip())
# print(len(individual))
# Out:
# Enter a Sentence / String My name is Mrinmoy Bordoloi
# M y   n a m e   i s   M r i n m o y   B o r d o l o i The number of occurances of a = 1
# The number of occurances of e = 1
# The number of occurances of i = 3
# The number of occurances of o = 4
# The number of occurances of u = 0

# %%
import string
a=input("Enter a Sentence / String ")
arr=[]
arr=a
cnt=0
individual=[]


i=0
cnt=[0,0,0,0,0]
countchar=0
space=0
vowel=['a','e','i','o','u']
for i in range(len(a)):
    countchar+=1
    if(a[i]==" "):
        space+=1
    


individual=a.split()

print(individual)
for i in range(len(individual)):
    print(individual[i],end=" ")
   
print(len(individual))
nofword_length=len(individual)


print(f"Words------=> {nofword_length}")
print(f"Characters-=> {countchar}")
print(f"Spaces-----=> {space}")















# for i in individual:
#     if i in string.punctuation:
#         print(i)


# print(string.punctuation)
# print(f"The ")

# print(f"The no  of words = {len(individual)}")
# b=a.strip().split()
# print(b)
# arr=b

# for i in range(len(arr)):
#     individual.append(arr[i].strip())
#     print(arr[i])

# print(individual,end=" ")
# for i in range(len(arr)):
#  print(individual[i].strip().strip())
# print(len(individual))
# Out:
# Enter a Sentence / String My name is Mrinmoy Bordoloi
# ['My', 'name', 'is', 'Mrinmoy', 'Bordoloi']
# My name is Mrinmoy Bordoloi 5
# Words------=> 5
# Characters-=> 27
# Spaces-----=> 4

# %%
import string

arr:str
arr=input("Enter a String ")
print(arr.split())
print(arr)


count=0
for i in arr:
    if(i in string.punctuation):
        arr=arr.replace(i,"")
        


print(arr)
# Out:
# Enter a String My name isM r!@#oy
# ['My', 'name', 'isM', 'r!@#oy']
# My name isM r!@#oy
# My name isM roy

# %%
import numpy as np


# print(arr1.ndim)
# print(arr1.shape)
matrix=[]
print("Enter the dimensions of the array")
m=int(input("Enter the number of rows "))
n=int(input("Enter the number of columns "))
for i in range(m):
    a=[]
    for j in range(n):
        a.append(int(input(f"Enter a value ofentry->({i},{j}) ")))
    matrix.append(a)


print(matrix)


print("-----------------------------------------------------")
for i in range(m):
    for j in range(n):
        print(f"{matrix[i][j]}",end=" ")
    print("\n")
print("-----------------------------------------------------")
# Out:
# Enter the dimensions of the array
# Enter the number of rows 2
# Enter the number of columns 2
# Enter a value ofentry->(0,0) 1
# Enter a value ofentry->(0,1) 2
# Enter a value ofentry->(1,0) 3
# Enter a value ofentry->(1,1) 4
# [[1, 2], [3, 4]]
# -----------------------------------------------------
# 1 2
#
# 3 4
#
# -----------------------------------------------------

# %%
import numpy as np


# print(arr1.ndim)
# print(arr1.shape)
matrix1=[]
print("Enter the dimensions of the matrix1")
m=int(input("Enter the number of rows "))
n=int(input("Enter the number of columns "))
for i in range(m):
    a=[]
    for j in range(n):
        a.append(int(input(f"Enter a value ofentry->({i},{j}) ")))
    matrix1.append(a)


print(matrix1)


print("----------------------------")
for i in range(m):
    for j in range(n):
        print(f"{matrix1[i][j]}",end=" ")
    print("\n")
print("----------------------------")

matrix2=[]
print("Enter the dimensions of the matrix1")
m2=int(input("Enter the number of rows "))
n2=int(input("Enter the number of columns "))
for i in range(m2):
    a2=[]
    for j in range(n2):
        a2.append(int(input(f"Enter a value ofentry->({i},{j}) ")))
    matrix2.append(a2)


print(matrix2)


print("----------------------------")
for i in range(m2):
    for j in range(n2):
        print(f"{matrix2[i][j]}",end=" ")
    print("\n")
print("----------------------------")

print("THE ADDITION OF THE MATRICES")


for i in range(m):
    for j in range(n):
        print(f"{matrix1[i][j]}",end=" ")
    print("\n")



print("\n+\n")


for i in range(m2):
    for j in range(n2):
        print(f"{matrix2[i][j]}",end=" ")
    print("\n")
    
print("\n")
addmatrix=[]
for i in range(m):
    a3=[]
    for j in range(n):
        a3.append((matrix1[i][j]+matrix2[i][j]))
    addmatrix.append(a3)

print("\n=\n")

for i in range(m):
    for j in range(n):
        print(addmatrix[i][j],end=" ")
    print("\n")


print("THE MULTIPLICATION OF THE MATRICES")


for i in range(m):
    for j in range(n):
        print(f"{matrix1[i][j]}",end=" ")
    print("\n")



print("\n+\n")


for i in range(m2):
    for j in range(n2):
        print(f"{matrix2[i][j]}",end=" ")
    print("\n")
    
print("\n")
addmatrix=[]
for i in range(m):
    a3=[]
    for j in range(n):
        a3.append((matrix1[i][j]*matrix2[i][j]))
    addmatrix.append(a3)

print("\n=\n")

for i in range(m):
    for j in range(n):
        print(addmatrix[i][j],end=" ")
    print("\n")


print("THE TRANSPOSE OF THE MATRICES")


for i in range(m):
    for j in range(n):
        print(f"{matrix1[i][j]}",end=" ")
    print("\n")


res1=[]
for i in range(m):
    a=[]
    for j in range(n):
        a.append(0)
    res1.append(a)

for i in range(m):
    for j in range(n):
        ap= matrix1[j][i]
        res1[i][j]=ap
    print("\n")



print("\n=\n")

for i in range(m):
    for j in range(n):
        print(f"{res1[i][j]}",end=" ")
    print("\n")



print("----------------------------")
print("----------------------------")
print("----------------------------")

for i in range(m2):
    for j in range(n2):
        print(f"{matrix2[i][j]}",end=" ")
    print("\n")
print("----------------------------")

res2=[]
for i in range(m):
    a=[]
    for j in range(n):
        a.append(0)
    res2.append(a)
print("----------------------------")
for i in range(m2):
    for j in range(n2):
        ap=matrix2[i][j]
        res2[j][i]=ap
    print("\n")
print("----------------------------")



for i in range(m2):
    for j in range(n2):
        print(f"{res2[i][j]}",end=" ")
    print("\n")
print("----------------------------")
# Out:
# Enter the dimensions of the matrix1
# Enter the number of rows 2
# Enter the number of columns 2
# Enter a value ofentry->(0,0) 1
# Enter a value ofentry->(0,1) 2
# Enter a value ofentry->(1,0) 3
# Enter a value ofentry->(1,1) 4
# [[1, 2], [3, 4]]
# ----------------------------
# 1 2
#
# 3 4
#
# ----------------------------
# Enter the dimensions of the matrix1
# Enter the number of rows 2
# Enter the number of columns 2
# Enter a value ofentry->(0,0) 5
# Enter a value ofentry->(0,1) 6
# Enter a value ofentry->(1,0) 7
# Enter a value ofentry->(1,1) 8
# [[5, 6], [7, 8]]
# ----------------------------
# 5 6
#
# 7 8
#
# ----------------------------
# THE ADDITION OF THE MATRICES
# 1 2
#
# 3 4
#
#
# +
#
# 5 6
#
# 7 8
#
#
#
#
# =
#
# 6 8
#
# 10 12
#
# THE MULTIPLICATION OF THE MATRICES
# 1 2
#
# 3 4
#
#
# +
#
# 5 6
#
# 7 8
#
#
#
#
# =
#
# 5 12
#
# 21 32
#
# THE TRANSPOSE OF THE MATRICES
# 1 2
#
# 3 4
#
#
#
#
#
#
# =
#
# 1 3
#
# 2 4
#
# ----------------------------
# ...
