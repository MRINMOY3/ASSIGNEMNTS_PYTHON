# %% [markdown]
# # Python Tasks – Day14
#
#
#
# # Program to find the sum of digits of a number until the sum is reduced to 1 digit.
#
# # Program to find LCM and HCF of two numbers.
#
# # Write a program to accept any number n and print the cube of all numbers from 1 to n which are divisible by 3. Rewrite the program using a continue statement.
#
# # Write a program to read roll numbers and marks of 10 students in 3 subjects. The valid range for roll number is 1000-9999, if the roll number entered is not in this range, the user should be asked to enter again. Calculate total marks of only those students who get more than or equal to 40 marks in each subject. Count the number of students whose total is more than 200. Print the roll number of the students who get the highest total.
#
# # Write a program to input a number and count the digits in it. Use while loop and the program should work correctly for 0 also.
#
# # Write a program to enter a number and find the reverse of that number. Also display the double of the reverse number. (don’t use string magic)

# %%
"""
The Python task DAY - 14
"""
arr=[]
a=(input("Enter a number "))
print(a)
# brr=
# for i in range()
##
arr=a.strip()
print(f"The number entered is = {arr}, \n AND the sum of number till last  digit is as follows UNTIL SUM REDUCED TO ONE DIGIT")



cnt=0;

for i in range(len(arr)):
    cnt+=int(arr[i])


for i in range(len(arr)):
    print(f"{arr[i]} ",end="")
    if(i<(len(arr)-1)):
        print(" + ",end="")
print(f" = {cnt}")

print("Performing Manually")
n=0
b=int(a)
sum=0
while(b>0):
    r=b%10
    sum+=r
    b=b//10

print(f"Manual Sum -->> {sum}")
# Out:
# Enter a number 1234
# 1234
# The number entered is = 1234,
#  AND the sum of number till last  digit is as follows UNTIL SUM REDUCED TO ONE DIGIT
# 1  + 2  + 3  + 4  = 10
# Performing Manually
# Manual Sum -->> 10

# %%
"""
int main() {
  int a, b, x, y, t, gcd, lcm;

  printf("Enter two integers\n");
  scanf("%d%d", &x, &y);

  a = x;
  b = y;

  while (b != 0) {
    t = b;
    b = a % b;
    a = t;
  }

  gcd = a;
  lcm = (x*y)/gcd;

  printf("Greatest common divisor of %d and %d = %d\n", x, y, gcd);
  printf("Least common multiple of %d and %d = %d\n", x, y, lcm);

  return 0;
}
"""

print("The H.C.F and the L.C.M of Two Numbers")
x=int(input("Enter the number 1 : - "))
y=int(input("Enter the number 2 : - "))
a=x
b=y

while(b!=0):
    t=b
    b=a%b
    a=t
gcd=a
lcm=(x*y)//gcd

print(f"G.C.D of {x} and {y} = {gcd}")
print(f"L.C.M of {x} and {y} = {lcm}")
# Out:
# The H.C.F and the L.C.M of Two Numbers
# Enter the number 1 : - 12
# Enter the number 2 : - 24
# G.C.D of 12 and 24 = 12
# L.C.M of 12 and 24 = 24

# %%
a=int(input("Enter a Number "))
i:int
arr=[]
brr=[]
i=1
for i in range(a):
    b=i**3
    if(b%3==0):
            arr.append(i)
    i+=1

i=0
for i in range(len(arr)):
      print(arr[i],end=" ")



print("\nRewriting using CONTINUE statement ")
i=0
for i in range(a):
    b=i**3
    if(b%3!=0):## If condition nis true that b%3!=0 then continue -->> reset the looping process again
          continue
    else:
          brr.append(i)
    i+=1 
i=0
for i in range(len(brr)):
      print(brr[i],end=" ")
# Out:
# Enter a Number 12
# 0 3 6 9
# Rewriting using CONTINUE statement
# 0 3 6 9

# %%
class Student:
    RollNo:int
    Marks=[]
    SpecialStudent=[]
    SpecialStudentName=[]
    x=0
    count=0

    def __init__(self,RollNo,Marks=[]):
        x=0;y=0;z=0
        ran=range(1000,9999)
        print(RollNo)
        if(RollNo in ran):
                print("The roll no is in Range")
                self.RollNo=RollNo
        else:
                print("The roll No is not in Range")
        self.Marks=Marks
        
                
                    

    def Getdata(self):
        
        print("The marks of the students are as follows : - ")
        print("----------------------------------------------------------")
        print("Roll No ",self.RollNo)
        for i in range(3):
            print(f"The marks in subject {i+1} = [{self.Marks[i]}]")

                  
        print("----------------------------------------------------------")

    
    def SumOfMarks(self):
            x=0
            for i in range(3):
                if(self.Marks[i]>=40):
                    self.x+=1
            if(self.x==3):
                        self.count+=1
                        for i in range(3):
                            self.SpecialStudent.append(self.Marks[i])
                        
                        self.SpecialStudentName.append(self.RollNo)
                        print(f"{self.RollNo} Secured >=40 in all the subjects")
            else:
                    print("Not a student who secured >=40 in all the Subjects")
            print(f"For the student with ROLL NUMBER {self.RollNo}")
            sum=0
            print("The sum of marks of the student who secured >=40 in All The Subjects")

            if(len(self.SpecialStudent)>0):
                for i in range(3):
                    sum+=self.SpecialStudent[i]
            
            print(f"The sum of the marks of the Student Who secured >=40 marks in all subject is = {sum}")
            # print("Not a student who secured >=40 in all the Subjects")
     

    def Count_TotalStudentwithmorethan40marks(self):
         print(f"The total number of students who secured more than 40 marks = {self.count}")
         

         




s1=[]
i=0
print("Getting Input of 10 student roll No ")
Mark=[]

print("Enter the number of STUDENTS in the DATA BASE ")
b=int(input())

for i in range(b):
    print(f"Enter the Details of STUDENT {i+1} ")
    RollNo=int(input("Enter Roll Number "))
    if(RollNo not in range(1000,9999)):
        #  restart=True## Restarting the LOOP
         print("Invalid roll number || Not in range 1000 , 9999, Enter Again")
         while(RollNo not in range(1000,9999)):
            print("Invalid roll number || Not in range 1000 , 9999, Enter Again")
            RollNo=int(input("Enter Roll Number "))
         ## Restarting the LOOP
         
    else:
         print(f"Roll No -> {RollNo} is accepted ")
        
    for i in range(3):
         mrk=int(input(f"Enter the marks in Subject {i+1} - "))
         Mark.append(mrk)
    s1.append(Student(RollNo,Mark))


for obj in s1:
     obj.Getdata()
     obj.SumOfMarks()
     obj.Count_TotalStudentwithmorethan40marks()
# Out:
# Getting Input of 10 student roll No
# Enter the number of STUDENTS in the DATA BASE
# 3
# Enter the Details of STUDENT 1
# Enter Roll Number 2105039
# Invalid roll number || Not in range 1000 , 9999, Enter Again
# Invalid roll number || Not in range 1000 , 9999, Enter Again
# Enter Roll Number 1001
# Enter the marks in Subject 1 - 100
# Enter the marks in Subject 2 - 100
# Enter the marks in Subject 3 - 100
# 1001
# The roll no is in Range
# Enter the Details of STUDENT 2
# Enter Roll Number 1002
# Roll No -> 1002 is accepted
# Enter the marks in Subject 1 - 99
# Enter the marks in Subject 2 - 99
# Enter the marks in Subject 3 - 99
# 1002
# The roll no is in Range
# Enter the Details of STUDENT 3
# Enter Roll Number 1003
# Roll No -> 1003 is accepted
# Enter the marks in Subject 1 - 99
# Enter the marks in Subject 2 - 98
# Enter the marks in Subject 3 - 99
# 1003
# The roll no is in Range
# The marks of the students are as follows : -
# ...
